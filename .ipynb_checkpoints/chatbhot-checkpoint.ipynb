# %%
#import some important library 
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data = json.loads(open('intents.json').read())

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
print(words)
# Out:
# ["'s", 'a', 'accept', 'anyone', 'are', 'bye', 'can', 'card', 'cash', 'credit', 'day', 'delivery', 'do', 'doe', 'funny', 'get', 'good', 'goodbye', 'have', 'hello', 'helpful', 'hey', 'hi', 'how', 'i', 'is', 'item', 'joke', 'kind', 'know', 'later', 'long', 'lot', 'mastercard', 'me', 'my', 'of', 'only', 'pay', 'paypal', 'see', 'sell', 'shipping', 'something', 'take', 'tell', 'thank', 'thanks', 'that', 'there', 'what', 'when', 'which', 'with', 'you']

# %%
print(classes)
# Out:
# ['delivery', 'funny', 'goodbye', 'greeting', 'items', 'payments', 'thanks']

# %%
print(doc_X)
# Out:
# ['Hi', 'Hey', 'How are you', 'Is anyone there?', 'Hello', 'Good day', 'Bye', 'See you later', 'Goodbye', 'Thanks', 'Thank you', "That's helpful", "Thank's a lot!", 'Which items do you have?', 'What kinds of items are there?', 'What do you sell?', 'Do you take credit cards?', 'Do you accept Mastercard?', 'Can I pay with Paypal?', 'Are you cash only?', 'How long does delivery take?', 'How long does shipping take?', 'When do I get my delivery?', 'Tell me a joke!', 'Tell me something funny!', 'Do you know a joke?']

# %%
print(doc_y)
# Out:
# ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'goodbye', 'goodbye', 'goodbye', 'thanks', 'thanks', 'thanks', 'thanks', 'items', 'items', 'items', 'payments', 'payments', 'payments', 'payments', 'delivery', 'delivery', 'delivery', 'funny', 'funny', 'funny']

# %%
# list for training data
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %%
# defining some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 128)               7168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 15,879
# Trainable params: 15,879
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0029 - accuracy: 0.1154
# Epoch 2/200
# 1/1 [==============================] - 0s 1000us/step - loss: 1.9560 - accuracy: 0.1154
# Epoch 3/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8206 - accuracy: 0.2308
# Epoch 4/200
# 1/1 [==============================] - 0s 997us/step - loss: 1.7238 - accuracy: 0.4231
# Epoch 5/200
# 1/1 [==============================] - 0s 993us/step - loss: 1.5994 - accuracy: 0.4615
# Epoch 6/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3890 - accuracy: 0.6923
# Epoch 7/200
# 1/1 [==============================] - 0s 1000us/step - loss: 1.3609 - accuracy: 0.6923
# Epoch 8/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1613 - accuracy: 0.7308
# Epoch 9/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0297 - accuracy: 0.8077
# Epoch 10/200
# 1/1 [==============================] - 0s 996us/step - loss: 0.7794 - accuracy: 0.8462
# Epoch 11/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6565 - accuracy: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6606 - accuracy: 0.9231
# Epoch 13/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4950 - accuracy: 0.9231
# Epoch 14/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4513 - accuracy: 0.9615
# Epoch 15/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4304 - accuracy: 0.8846
# Epoch 16/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2141 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2352 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1788 - accuracy: 0.9615
# Epoch 20/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0759 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1125 - accuracy: 0.9615
# Epoch 22/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0871 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6725e-04 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9615
# Epoch 46/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4044e-04 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 999us/step - loss: 5.2862e-04 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9615
# Epoch 54/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.9615
# Epoch 58/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9328e-04 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6127e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.9615
# Epoch 71/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5652e-05 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 3ms/step - loss: 9.8087e-04 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1355e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7966e-04 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 999us/step - loss: 2.9408e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.2410e-04 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0516 - accuracy: 0.9615
# Epoch 97/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2267e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1980e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 999us/step - loss: 7.9699e-05 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5044e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6664e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 999us/step - loss: 5.0840e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 999us/step - loss: 2.2899e-04 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 999us/step - loss: 7.6253e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2882e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9836e-04 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6305e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.6896e-05 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.6731e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 1000us/step - loss: 1.3055e-04 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6609e-04 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1510e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6251e-05 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 996us/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 999us/step - loss: 5.8867e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4217e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2139e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 999us/step - loss: 7.8744e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 998us/step - loss: 9.1776e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6424e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4500e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 997us/step - loss: 0.0323 - accuracy: 0.9615
# Epoch 136/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.1829e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7391e-04 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2920e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5522e-05 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7065e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7093e-04 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8632e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2395e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 999us/step - loss: 1.1283e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 999us/step - loss: 9.6027e-04 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4650e-04 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 998us/step - loss: 3.2555e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9654e-05 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6158e-04 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4562e-05 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.9547e-06 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4888e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 998us/step - loss: 1.0815e-04 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 1ms/step - loss: 8.3623e-05 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 999us/step - loss: 1.0914e-04 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7388e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0036e-05 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.8097e-04 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3441e-04 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.9108e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 998us/step - loss: 6.1044e-05 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 1000us/step - loss: 9.6627e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 999us/step - loss: 5.8588e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5593e-04 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 999us/step - loss: 9.4029e-05 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7814e-04 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 998us/step - loss: 7.4082e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4547e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 1000us/step - loss: 1.1939e-04 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1991e-04 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5715e-04 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4624e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3384e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4025e-06 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 999us/step - loss: 2.4372e-05 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 999us/step - loss: 6.1970e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9615
# Epoch 188/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9506e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 3ms/step - loss: 8.9132e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0017e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6768e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 999us/step - loss: 3.1612e-05 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 998us/step - loss: 6.9986e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3715e-05 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 998us/step - loss: 9.2697e-04 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9615
# Epoch 198/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 999us/step - loss: 6.1927e-04 - accuracy: 1.0000

# %%
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text, vocab): 
    tokens = clean_text(text)
    bow = [0] * len(vocab)
    for w in tokens: 
        for idx, word in enumerate(vocab):
            if word == w: 
                bow[idx] = 1
    return np.array(bow)

def pred_class(text, vocab, labels):
    bow = bag_of_words(text, vocab)
    result = model.predict(np.array([bow]))[0]
    thresh = 0.2
    y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

    y_pred.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in y_pred:
        return_list.append(labels[r[0]])
    return return_list

def get_response(intents_list, intents_json): 
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents: 
        if i["tag"] == tag:
            result = random.choice(i["responses"])
        break
    return result

# %%
# running the chatbot
while True:
    message = input("")
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    if (message ==result):
        print(result)
    else:
        print("Your output is not here")
# Out:
# house
# Your output is not here
# sound
# Your output is not here
# payment
# Your output is not here
# goodbye
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8356/1786256396.py in <module>
#       3     message = input("")
#       4     intents = pred_class(message, words, classes)
# ----> 5     result = get_response(intents, data)
#       6     if (message ==result):
#       7         print(result)
#
# ~\AppData\Local\Temp/ipykernel_8356/4284808292.py in get_response(intents_list, intents_json)
#      32             result = random.choice(i["responses"])
#      33         break
# ---> 34     return result
#
# UnboundLocalError: local variable 'result' referenced before assignment
